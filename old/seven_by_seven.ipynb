# %% [markdown]
# ### 11/11
# * Try to make a random agent moving pieces on the board
# * 1 for win, 0 for loss or tie
# * Over time need to bake in the learning component of how would each player learn to play the best?
#
# ### To research:
# * How to encode the possible different states (and how large is the state space in general)?
# * Minimax functions
# * Alpha/Beta pruning

# %%
import numpy as np
import pandas as pd

print('Numpy: ', np.__version__)
print('Pandas: ', pd.__version__)
# Out:
# Numpy:  1.21.4
# Pandas:  1.3.4

# %%
# create a class that has a board game 

class hnefataflEnv: 
    
    def __init__(self:
